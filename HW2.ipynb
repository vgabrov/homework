# %%
# Homework 2
# Задача 2. Мы делаем MVP dating-сервиса, и у нас есть список парней и девушек (их число может варьироваться):

#In [9]:
#boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
#girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']
#Выдвигаем гипотезу: лучшие рекомендации мы получим, если просто отсортируем имена по алфавиту и познакомим людей с одинаковыми индексами после сортировки! "Познакомить" пары нам поможет функция zip, а в цикле распакуем zip-объект и выведем информацию в виде:

#Идеальные пары:
#Alex и Emma
#Arthur и Kate
#John и Kira
#Peter и Liza
#Richard и Trisha

#Внимание! Если количество людей в списках будет не совпадать, то мы никого знакомить не будет и выведем пользователю предупреждение, что кто-то может остаться без пары!

boys = ['Peter', 'Alex', 'John', 'Arthur', 'Richard']
girls = ['Kate', 'Liza', 'Kira', 'Emma', 'Trisha']

if len(boys)!=len(girls):
    print("Количество парней и девушек не совпадает, кто-то может остаться без пары!")
else:
    boys_sorted=sorted(boys)
    girls_sorted=sorted(girls)
    print('Идеальные пары:')
#   print(f'{boys_sorted[0]}')
    i=0
    while i in range(0,len(boys_sorted)):
        print(f'{boys_sorted[i]} и {girls_sorted[i]}')
        i+=1
# Out:
# Идеальные пары:
# Alex и Emma
# Arthur и Kate
# John и Kira
# Peter и Liza
# Richard и Trisha

# %%
# Homework 2
# Задача 3. У нас есть список, содержащий информацию о среднедневной температуре в Фаренгейтах за недельный период по странам. 
# Необходимо написать код, который рассчитает среднюю температуру за неделю в Цельсиях для каждой страны.


countries_temperature = [
 ['Thailand', [75.2, 77, 78.8, 73.4, 68, 75.2, 77]],
 ['Germany', [57.2, 55.4, 59, 59, 53.6, 55.4, 57.2]],
 ['Russia', [35.6, 37.4, 39.2, 41, 42.8, 39.2, 35.6]],
 ['Poland', [50, 50, 53.6, 57.2, 55.4, 55.4, 51.8]],
]

def temp_celcius_average(country_data):
    country_celcius_average=list()
    for i in range(0,len(country_data)):
        #while j in range (0,len(country_data[i][1])):
        country_celcius_average.append((sum(country_data[i][1])/len(country_data[i][1])-32)*5/9)
    return country_celcius_average
       
for i in range (0,len(countries_temperature)):
    print(f'{countries_temperature[i][0]} = {round(temp_celcius_average(countries_temperature)[i],2)}')
# Out:
# Thailand = 23.86
# Germany = 13.71
# Russia = 3.71
# Poland = 11.86

# %%
# Homework 2
# Задача 4. Дан поток логов по количеству просмотренных страниц для каждого пользователя. Список отсортирован по ID пользователя. 
# Вам необходимо написать алгоритм, который считает среднее значение просмотров на пользователя. 
# Т. е. надо посчитать отношение суммы всех просмотров к количеству уникальных пользователей.


import collections

stream = [
    '2018-01-01,user1,3',
    '2018-01-07,user1,4',
    '2018-03-29,user1,1',
    '2018-04-04,user1,13',
    '2018-01-05,user2,7',
    '2018-06-14,user3,4',
    '2018-07-02,user3,10',
    '2018-03-21,user4,19',
    '2018-03-22,user4,4',
    '2018-04-22,user4,8',
    '2018-05-03,user4,9',
    '2018-05-11,user4,11',
]

#Двигаться по исходной структуре циклом for, разбивать строки на списки при помощи метода split, 
#пользователей накапливать во вспомогательный список (только без повторов) и сразу считать сумму просмотров.
#Потом просто поделить количество просмотров на длину списка уникальных пользователей. Просьба это доработать.

def average_views_per_user(log):
    users_split=list()
    views_sum=users_sum=0
    for i in range(0,len(log)):
        views_sum+=int(log[i].split(",")[2])
        users_split.append(log[i].split(",")[1])
    unique_users=list(set(users_split))
    users_sum=len(unique_users)
    print (f'Всего просмотров: {views_sum}, Уникальных пользователей: {users_sum}')
    print (f'Просмотров в среднем на 1 пользователя: {views_sum/users_sum}')

average_views_per_user(stream)

#??
#def average_views_per_user(log):
#    user_views_count = list()
#    start = 'user'
#    end = ','
#    while i in range(0,len(log):
#        user_views_count.append([log.find(start)+len(start):s.rfind(end)]
#    return user_views

    
#print(average_views_per_user(stream))
#??
# Out:
# Всего просмотров: 93, Уникальных пользователей: 4
# Просмотров в среднем на 1 пользователя: 23.25

# %%
# Homework 2
# Задача 5. Дана статистика рекламных кампаний по дням. 
# Напишите алгоритм, который по паре дата-кампания ищет значение численного столбца. 
# Т. е. для даты '2018-01-01' и 'google' нужно получить число 25. Считайте, что все комбинации дата-кампания уникальны.


stats = [
    ['2018-01-01', 'google', 25],
    ['2018-01-01', 'yandex', 65],
    ['2018-01-01', 'market', 89],
    ['2018-01-02', 'google', 574],
    ['2018-01-02', 'yandex', 249],
    ['2018-01-02', 'market', 994],
    ['2018-01-03', 'google', 1843],
    ['2018-01-03', 'google', 1327],
    ['2018-01-03', 'market', 1764],
]

date = input("Введите дату (строку для поиска): ")
company = input("Введите название компании (строку для поиска): ")
indexes = list()
i=0
while i < len(stats):
    if stats[i][0]==date and stats[i][1]==company:
        print ("Найдено")
        indexes.append(stats[i][2])
    i+=1
        
print (f'Индексы: {indexes}')
# Out:
# Введите дату (строку для поиска): 2018-01-03
# Введите название компании (строку для поиска): google
# Найдено
# Найдено
# Индексы: [1843, 1327]

# %%
# Homework 2
# Задача 6. Дан список.
# Напишите код, который будет вычислять сумму элементов на диагонали. Т. е. 13+32+23+35.
# Список может быть любой длины, но всегда является "квадратным" (количество элементов во вложенных списках равно их количеству).

data = [
    [13, 25, 23, 34],
    [45, 32, 44, 47],
    [12, 33, 23, 95],
    [13, 53, 34, 35]
]

diag_sum=i=j=0

while i<len(data):
    diag_sum+=data[i][j]
    i+=1

print (diag_sum)
# Out:
# 83

# %%
# Homework 3
# Задание 1. Дан список с визитами по городам и странам. 
# Напишите код, который возвращает отфильтрованный список geo_logs, содержащий только визиты из России.

geo_logs = [
    {'visit1': ['Москва', 'Россия']},
    {'visit2': ['Дели', 'Индия']},
    {'visit3': ['Владимир', 'Россия']},
    {'visit4': ['Лиссабон', 'Португалия']},
    {'visit5': ['Париж', 'Франция']},
    {'visit6': ['Лиссабон', 'Португалия']},
    {'visit7': ['Тула', 'Россия']},
    {'visit8': ['Тула', 'Россия']},
    {'visit9': ['Курск', 'Россия']},
    {'visit10': ['Архангельск', 'Россия']}
]

geo_logs_Russia=list()

for i in range(0,len(geo_logs)):
    for key in geo_logs[i]:
        print(f'Визит {i+1}: {geo_logs[i][key]}')
        if geo_logs[i][key][1]=='Россия':
            geo_logs_Russia.append(geo_logs[i])

print (f'\nВизиты по России: {geo_logs_Russia}')
# Out:
# Визит 1: ['Москва', 'Россия']
# Визит 2: ['Дели', 'Индия']
# Визит 3: ['Владимир', 'Россия']
# Визит 4: ['Лиссабон', 'Португалия']
# Визит 5: ['Париж', 'Франция']
# Визит 6: ['Лиссабон', 'Португалия']
# Визит 7: ['Тула', 'Россия']
# Визит 8: ['Тула', 'Россия']
# Визит 9: ['Курск', 'Россия']
# Визит 10: ['Архангельск', 'Россия']
#
# Визиты по России: [{'visit1': ['Москва', 'Россия']}, {'visit3': ['Владимир', 'Россия']}, {'visit7': ['Тула', 'Россия']}, {'visit8': ['Тула', 'Россия']}, {'visit9': ['Курск', 'Россия']}, {'visit10': ['Архангельск', 'Россия']}]
